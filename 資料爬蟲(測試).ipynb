# %%
import requests
#from bs4 import BeautifulSoup
#import selenium
#from selenium import webdriver
#from selenium.webdriver.support.ui import Select
from datetime import datetime
import json
import os
datetime.now()
import time

# %%
bigmonth = ['01','03','05','07','08','10','12']
smallmonth = ['04','06']#,'09','11']
specialmonth = ['01','02']

# %%
for month in bigmonth:
    for i in range(1,32):
        if i < 10:
            i = '0'+str(i)
        else:
            i = str(i)
        date = '2020'+month+i
        print(date)
        url = 'https://www.twse.com.tw/fund/T86?response=csv&date='+date+'&selectType=ALL'
        response = requests.get(url)
        print(f'結果回傳: {response}')
        filename = date+'.txt'
        print(filename)
        key = '三大法人買賣超日報'
        if key in response.text:
            with open(filename,'w+',encoding='utf8') as f:
                f.write(response.text)
            print(f'寫入完成: {filename}\n\n')
        else:
            print(f'今天假日\n\n')
        print(f'=============== {datetime.now()} =================')
        time.sleep(5)
# Out:
# 20200301
# 結果回傳: <Response [200]>
# 20200301.txt
# 今天假日
#
#
# =============== 2020-08-20 21:34:01.386507 =================
# 20200302
# 結果回傳: <Response [200]>
# 20200302.txt
# 寫入完成: 20200302.txt
#
#
# =============== 2020-08-20 21:34:11.499463 =================
# 20200303
# 結果回傳: <Response [200]>
# 20200303.txt
# 寫入完成: 20200303.txt
#
#
# =============== 2020-08-20 21:34:20.769291 =================
# 20200304
# 結果回傳: <Response [200]>
# 20200304.txt
# 寫入完成: 20200304.txt
#
#
# =============== 2020-08-20 21:34:31.623320 =================
# 20200305
# 結果回傳: <Response [200]>
# 20200305.txt
# 寫入完成: 20200305.txt
#
#
# =============== 2020-08-20 21:34:41.115812 =================
# 20200306
# 結果回傳: <Response [200]>
# 20200306.txt
# 寫入完成: 20200306.txt
#
#
# =============== 2020-08-20 21:34:49.388157 =================
# 20200307
# 結果回傳: <Response [200]>
# 20200307.txt
# 今天假日
#
#
# =============== 2020-08-20 21:34:54.765661 =================
# 20200308
# 結果回傳: <Response [200]>
# 20200308.txt
# ...

# %%
for month in smallmonth:
    for i in range(1,31):
        if i < 10:
            i = '0'+str(i)
        else:
            i = str(i)
        date = '2020'+month+i
        print(date)
        url = 'https://www.twse.com.tw/fund/T86?response=csv&date='+date+'&selectType=ALL'
        response = requests.get(url)
        print(f'結果回傳: {response}')
        filename = date+'.txt'
        print(filename)
        key = '三大法人買賣超日報'
        if key in response.text:
            with open(filename,'w+',encoding='utf8') as f:
                f.write(response.text)
            print(f'寫入完成: {filename}\n\n')
        else:
            print(f'今天假日\n\n')
        print(f'=============== {datetime.now()} =================')
        time.sleep(5)

for month in specialmonth:
    for i in range(1,30):
        if i < 10:
            i = '0'+str(i)
        else:
            i = str(i)
        date = '2020'+month+i
        print(date)
        url = 'https://www.twse.com.tw/fund/T86?response=csv&date='+date+'&selectType=ALL'
        response = requests.get(url)
        print(f'結果回傳: {response}')
        filename = date+'.txt'
        print(filename)
        key = '三大法人買賣超日報'
        if key in response.text:
            with open(filename,'w+',encoding='utf8') as f:
                f.write(response.text)
            print(f'寫入完成: {filename}\n\n')
        else:
            print(f'今天假日\n\n')
        print(f'=============== {datetime.now()} =================')
        time.sleep(5)
# Out:
# 20200401
# 結果回傳: <Response [200]>
# 20200401.txt
# 寫入完成: 20200401.txt
#
#
# =============== 2020-08-20 21:54:31.281878 =================
# 20200402
# 結果回傳: <Response [200]>
# 20200402.txt
# 今天假日
#
#
# =============== 2020-08-20 21:54:36.691255 =================
# 20200403
# 結果回傳: <Response [200]>
# 20200403.txt
# 今天假日
#
#
# =============== 2020-08-20 21:54:42.553285 =================
# 20200404
# 結果回傳: <Response [200]>
# 20200404.txt
# 今天假日
#
#
# =============== 2020-08-20 21:54:48.444249 =================
# 20200405
# 結果回傳: <Response [200]>
# 20200405.txt
# 今天假日
#
#
# =============== 2020-08-20 21:54:54.113719 =================
# 20200406
# 結果回傳: <Response [200]>
# 20200406.txt
# 寫入完成: 20200406.txt
#
#
# =============== 2020-08-20 21:55:01.992113 =================
# 20200407
# 結果回傳: <Response [200]>
# 20200407.txt
# 寫入完成: 20200407.txt
#
#
# =============== 2020-08-20 21:55:10.782496 =================
# 20200408
# 結果回傳: <Response [200]>
# 20200408.txt
# 寫入完成: 20200408.txt
#
#
# ...

# %%
for month in specialmonth:
    for i in range(1,32):
        if i < 10:
            i = '0'+str(i)
        else:
            i = str(i)
        date = '2020'+month+i
        print(date)
        url = 'https://www.twse.com.tw/fund/T86?response=csv&date='+date+'&selectType=ALL'
        response = requests.get(url)
        print(f'結果回傳: {response}')
        filename = date+'.txt'
        print(filename)
        key = '三大法人買賣超日報'
        if key in response.text:
            with open(filename,'w+',encoding='utf8') as f:
                f.write(response.text)
            print(f'寫入完成: {filename}\n\n')
        else:
            print(f'今天假日\n\n')
        print(f'=============== {datetime.now()} =================')
        time.sleep(5)
# Out:
# 20200101
# 結果回傳: <Response [200]>
# 20200101.txt
# 今天假日
#
#
# =============== 2020-08-20 22:18:51.016939 =================
# 20200102
# 結果回傳: <Response [200]>
# 20200102.txt
# 寫入完成: 20200102.txt
#
#
# =============== 2020-08-20 22:19:04.208497 =================
# 20200103
# 結果回傳: <Response [200]>
# 20200103.txt
# 寫入完成: 20200103.txt
#
#
# =============== 2020-08-20 22:19:26.395926 =================
# 20200104
# 結果回傳: <Response [200]>
# 20200104.txt
# 今天假日
#
#
# =============== 2020-08-20 22:19:38.802198 =================
# 20200105
# 結果回傳: <Response [200]>
# 20200105.txt
# 今天假日
#
#
# =============== 2020-08-20 22:19:44.391216 =================
# 20200106
# 結果回傳: <Response [200]>
# 20200106.txt
# 寫入完成: 20200106.txt
#
#
# =============== 2020-08-20 22:20:34.003263 =================
# 20200107
# 結果回傳: <Response [200]>
# 20200107.txt
# 寫入完成: 20200107.txt
#
#
# =============== 2020-08-20 22:21:12.086851 =================
# 20200108
# 結果回傳: <Response [200]>
# 20200108.txt
# ...

# %%
date = '20200820'
url = 'https://www.twse.com.tw/fund/T86?response=csv&date='+date+'&selectType=ALL'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
month_in_year = ['01','02','03','04','05','06','07','08']#,'09','10','11','12']
tw50 = [1101,1102,1216,1301,1303,1326,1402,2002,2105,2207,
        2301,2303,2308,2317,2327,2330,2357,2382,2395,2408,
        2412,2454,2474,2633,2801,2823,2881,2882,2883,2884,
        2885,2886,2887,2888,2890,2891,2892,2912,3008,3045,
        3711,4904,4938,5871,5876,5880,6505,6669,9910]


counter = 0
for stock in tw50:
    for month in month_in_year:
        stock = str(stock)
        month = str(month)
        counter += 1
        print(f'=============== {counter} {datetime.now()} =================')
        print(f'2020年 {month}月 股號{stock}')
        url = 'https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=csv&date=2020'+month+'01&stockNo='+stock
        print(url)
        response = requests.get(url)
        print(f'結果回傳: {response}')

        filename = stock+'_2020'+month+'.txt'
        print(filename)
        key = '各日成交資訊'
        if key in response.text:
            with open(filename,'w+',encoding='utf8') as f:
                f.write(response.text)
            print(f'寫入完成: {filename}\n\n')
        else:
            print(f'今天假日\n\n')
        time.sleep(5)
# Out:
# =============== 1 2020-08-20 22:59:19.231776 =================
# 2020年 01月 股號1101
# https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=csv&date=20200101&stockNo=1101
# 結果回傳: <Response [200]>
# 1101_202001.txt
# 寫入完成: 1101_202001.txt
#
#
# =============== 2 2020-08-20 22:59:24.805163 =================
# 2020年 02月 股號1101
# https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=csv&date=20200201&stockNo=1101
# 結果回傳: <Response [200]>
# 1101_202002.txt
# 寫入完成: 1101_202002.txt
#
#
# =============== 3 2020-08-20 22:59:29.885153 =================
# 2020年 03月 股號1101
# https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=csv&date=20200301&stockNo=1101
# 結果回傳: <Response [200]>
# 1101_202003.txt
# 寫入完成: 1101_202003.txt
#
#
# =============== 4 2020-08-20 22:59:35.000660 =================
# 2020年 04月 股號1101
# https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=csv&date=20200401&stockNo=1101
# 結果回傳: <Response [200]>
# 1101_202004.txt
# 寫入完成: 1101_202004.txt
#
#
# ...

# %%
counter = 0

mid100 = ["1210","1227","1229","1434","1476","1477","1504","1536","1590","1605",
          "1707","1717","1722","1723","1789","1802","2027","2049","2059","2101",
          "2201","2227","2313","2324","2337","2344","2345","2347","2352","2354",
          "2356","2360","2376","2377","2379","2383","2385","2404","2409","2439",
          "2448","2449","2451","2458","2492","2498","2542","2603","2606","2610",
          "2615","2618","2809","2812","2834","2867","2889","2903","2915","3005",
          "3023","3034","3037","3044","3231","3406","3443","3481","3532","3533",
          "3653","3702","3706","4958","5269","5522","6176","6213","6239","6269",
          "6278","6409","6415","6456","6592","8046","8341","8454","8464","9904",
          "9914","9917","9921","9933","9941","9945"]

for stock in mid100:
    for month in month_in_year:
        stock = str(stock)
        month = str(month)
        counter += 1
        print(f'=============== {counter}, {datetime.now()} =================')
        print(f'2020年 {month}月 股號{stock}')
        url = 'https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=csv&date=2020'+month+'01&stockNo='+stock
        print(url)
        response = requests.get(url)
        print(f'結果回傳: {response}')

        filename = stock+'_2020'+month+'.txt'
        print(filename)
        key = '各日成交資訊'
        if key in response.text:
            with open(filename,'w+',encoding='utf8') as f:
                f.write(response.text)
            print(f'寫入完成: {filename}\n\n')
        else:
            print(f'今天假日\n\n')
        time.sleep(5)
# Out:
# =============== 1, 2020-08-20 23:44:08.759269 =================
# 2020年 01月 股號1210
# https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=csv&date=20200101&stockNo=1210
# 結果回傳: <Response [200]>
# 1210_202001.txt
# 寫入完成: 1210_202001.txt
#
#
# =============== 2, 2020-08-20 23:44:14.001742 =================
# 2020年 02月 股號1210
# https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=csv&date=20200201&stockNo=1210
# 結果回傳: <Response [200]>
# 1210_202002.txt
# 寫入完成: 1210_202002.txt
#
#
# =============== 3, 2020-08-20 23:44:19.939728 =================
# 2020年 03月 股號1210
# https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=csv&date=20200301&stockNo=1210
# 結果回傳: <Response [200]>
# 1210_202003.txt
# 寫入完成: 1210_202003.txt
#
#
# =============== 4, 2020-08-20 23:44:25.693312 =================
# 2020年 04月 股號1210
# https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=csv&date=20200401&stockNo=1210
# 結果回傳: <Response [200]>
# 1210_202004.txt
# 寫入完成: 1210_202004.txt
#
#
# ...

# %%
filename = date+'.txt'
print(filename)

with open(filename,'w+',encoding='utf8') as f:
    f.write(response.text)
# Out:
# 20200820.txt

# %%
tw50 = [1101,1102,1216,1301,1303,1326,1402,2002,2105,2207,
        2301,2303,2308,2317,2327,2330,2357,2382,2395,2408,
        2412,2454,2474,2633,2801,2823,2881,2882,2883,2884,
        2885,2886,2887,2888,2890,2891,2892,2912,3008,3045,
        3711,4904,4938,5871,5876,5880,6505,6669,9910]
print(tw50)
# Out:
# [1101, 1102, 1216, 1301, 1303, 1326, 1402, 2002, 2105, 2207, 2301, 2303, 2308, 2317, 2327, 2330, 2357, 2382, 2395, 2408, 2412, 2454, 2474, 2633, 2801, 2823, 2881, 2882, 2883, 2884, 2885, 2886, 2887, 2888, 2890, 2891, 2892, 2912, 3008, 3045, 3711, 4904, 4938, 5871, 5876, 5880, 6505, 6669, 9910]

# %%
mid100 = ["1210","1227","1229","1434","1476","1477","1504","1536","1590","1605","1707","1717","1722","1723","1789","1802","2027","2049","2059","2101","2201","2227","2313","2324","2337","2344","2345","2347","2352","2354","2356","2360","2376","2377","2379","2383","2385","2404","2409","2439","2448","2449","2451","2458","2492","2498","2542","2603","2606","2610","2615","2618","2809","2812","2834","2867","2889","2903","2915","3005","3023","3034","3037","3044","3231","3406","3443","3481","3532","3533","3653","3702","3706","4958","5269","5522","6176","6213","6239","6269","6278","6409","6415","6456","6592","8046","8341","8454","8464","9904","9914","9917","9921","9933","9941","9945"]
len(mid100)
# Out:
# 96

# %%
# 開啟視窗
url = 'https://www.twse.com.tw/fund/T86?response=csv&date=20200820&selectType=ALL'

CSV_URL = url


with requests.Session() as s:
    download = s.get(CSV_URL)

    decoded_content = download.content.decode('utf-8')

# %%
# 選取月份
select0 = Select(driver.find_element_by_name('mm'))
select0.select_by_value("2")

# %%
# 選取日期
select1 = Select(driver.find_element_by_name('dd'))
select1.select_by_index(20)

# %%
# 選取類別>>全部
select2 = Select(driver.find_element_by_name('selectType'))
select2.select_by_value("ALL")

# %%
# 選取數量>>全部
select2 = Select(driver.find_element_by_name('report-table_length'))
select2.select_by_value("-1")

# %%
# 按下查詢
python_button = driver.find_element_by_class_name('main').find_element_by_css_selector('a')
python_button.click()

# %%
# 按下下載
python_button = driver.find_element_by_class_name('csv')
python_button.click()

# %%
# 取得原始碼
htmltext = driver.page_source
htmltext
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml"><head>\n    <meta http-equiv="X-UA-Compatible" content="IE=EmulateIE8">\n    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n    <title>4星彩 各期獎號與開獎結果</title>\n    <link href="/css1.css" rel="stylesheet" type="text/css">\n    \n    <script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-N6HP9ZR"></script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-N6HP9ZR\');</script>\n \n</head>\n<body>\n    <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-N6HP9ZR" height="0" width="0" style="
# ...

# %%
# 官網解析 取出table
soup = BeautifulSoup(htmltext, 'html.parser')
green_table = soup.find_all('table',class_='table_gre')
orange_table = soup.find_all('table',class_='table_org')
print(len(green_table))
print(len(orange_table))
# Out:
# 13
# 13

# %%
# 官網解析 重構table[測試區]
box = []

#for i,ele in enumerate(green_table[0].find_all('td',class_="td_gre1")):
#    string = ele.text.replace('\n','').replace('\r','').replace(' ','')
#    print(i,string)

print('=========================================================')
info = {'期別':None, '開獎日期':None, '獎號':None, '正彩':[], '4組彩':[], '6組彩':[], '12組彩':[], '24組彩':[], '金額':[]}
for i,ele in enumerate(green_table[6].find_all('td',class_="td_w")):
    string = ele.text.replace('\n','').replace('\r','').replace(' ','')
    print(i,string)
# Out:
# ...
# 0 105000117
# 1 開獎105/5/16
# 2 0339
# 3 中獎注數
# 4 8
# 5 0
# 6 0
# 7 75
# 8 0
# 9 銷售金額4,210,425
# 10 兌獎截止(註4)105/8/16
# 11 中獎組合
# 12 單注獎金
# 13 125,000
# 14 30,000
# 15 20,000
# 16 10,000
# 17 5,000
# 18 獎金總額1,750,000

# %%
# 官網解析 重構table(完成版)
for i in range(len(green_table)):
    info = {'期別':None, '開獎日期':None, '獎號':None, '正彩':[], '4組彩':[], '6組彩':[], '12組彩':[], '24組彩':[], '金額':[]}
    index = {'期別':0, '開獎日期':1, '獎號':2, '正彩':[4,13], '4組彩':[5,14], '6組彩':[6,15], '12組彩':[7,16], '24組彩':[8,17], '金額':[9,18]}
    raw_box = green_table[i].find_all('td',class_="td_w")
    info['期別'] = raw_box[0].text
    info['開獎日期'] = raw_box[1].text
    info['獎號'] = raw_box[2].text
    info['正彩'].append(raw_box[4].text)
    info['正彩'].append(raw_box[13].text)
    info['4組彩'].append(raw_box[5].text)
    info['4組彩'].append(raw_box[14].text)
    info['6組彩'].append(raw_box[6].text)
    info['6組彩'].append(raw_box[15].text)
    info['12組彩'].append(raw_box[7].text)
    info['12組彩'].append(raw_box[16].text)
    info['24組彩'].append(raw_box[8].text)
    info['24組彩'].append(raw_box[17].text)
    info['金額'].append(raw_box[9].text)
    info['金額'].append(raw_box[18].text)

    filename = info['期別']+'.txt'
    file_path = os.path.join(".\四星彩資料集", filename)
    with open(file_path,'w+',encoding='utf8') as f:
        json.dump(info, f, ensure_ascii=False, indent = 4)
    print(f'儲存完成... 檔案名稱:{file_path}')
    print(info)
    print('===============================================\n')
for i in range(len(orange_table)):
    info = {'期別':None, '開獎日期':None, '獎號':None, '正彩':[], '4組彩':[], '6組彩':[], '12組彩':[], '24組彩':[], '金額':[]}
    index = {'期別':0, '開獎日期':1, '獎號':2, '正彩':[4,13], '4組彩':[5,14], '6組彩':[6,15], '12組彩':[7,16], '24組彩':[8,17], '金額':[9,18]}
    raw_box = orange_table[i].find_all('td',class_="td_w")
    info['期別'] = raw_box[0].text
    info['開獎日期'] = raw_box[1].text
    info['獎號'] = raw_box[2].text
    info['正彩'].append(raw_box[4].text)
    info['正彩'].append(raw_box[13].text)
    info['4組彩'].append(raw_box[5].text)
    info['4組彩'].append(raw_box[14].text)
    info['6組彩'].append(raw_box[6].text)
    info['6組彩'].append(raw_box[15].text)
    info['12組彩'].append(raw_box[7].text)
    info['12組彩'].append(raw_box[16].text)
    info['24組彩'].append(raw_box[8].text)
    info['24組彩'].append(raw_box[17].text)
    info['金額'].append(raw_box[9].text)
    info['金額'].append(raw_box[18].text)

    filename = info['期別']+'.txt'
    file_path = os.path.join(".\四星彩資料集", filename)
    with open(file_path,'w+',encoding='utf8') as f:
        json.dump(info, f, ensure_ascii=False, indent = 4)
    print(f'儲存完成... 檔案名稱:{file_path}')
    print(info)
    print('===============================================\n')
# Out:
# 儲存完成... 檔案名稱:.\四星彩資料集\105000129.txt
# {'期別': '105000129', '開獎日期': '開獎105/5/30', '獎號': '3870', '正彩': ['4', '125,000'], '4組彩': ['0', '30,000'], '6組彩': ['0', '20,000'], '12組彩': ['0', '10,000'], '24組彩': ['115', '5,000'], '金額': ['銷售金額4,357,850', '獎金總額1,075,000']}
# ...
#
# 儲存完成... 檔案名稱:.\四星彩資料集\105000127.txt
# {'期別': '105000127', '開獎日期': '開獎105/5/27', '獎號': '2379', '正彩': ['22', '125,000'], '4組彩': ['0', '30,000'], '6組彩': ['0', '20,000'], '12組彩': ['0', '10,000'], '24組彩': ['239', '5,000'], '金額': ['銷售金額3,932,675', '獎金總額3,945,000']}
# ...
#
# 儲存完成... 檔案名稱:.\四星彩資料集\105000125.txt
# {'期別': '105000125', '開獎日期': '開獎105/5/25', '獎號': '1913', '正彩': ['31', '125,000'], '4組彩': ['0', '30,000'], '6組彩': ['0', '20,000'], '12組彩': ['101', '10,000'], '24組彩': ['0', '5,000'], '金額': ['銷售金額3,996,800', '獎金總額4,885,000']}
# ...
#
# 儲存完成... 檔案名稱:.\四星彩資料集\105000123.txt
# ...

# %%
info
# Out:
# {'期別': '105000117',
#  '開獎日期': '開獎105/5/16',
#  '獎號': '0339',
#  '正彩': ['8', '125,000'],
#  '4組彩': ['0', '30,000'],
#  '6組彩': ['0', '20,000'],
#  '12組彩': ['75', '10,000'],
#  '24組彩': ['0', '5,000'],
#  '金額': ['銷售金額4,210,425', '獎金總額1,750,000']}

# %%
import json
import os
filename = info['期別']+'.txt'
file_path = os.path.join(".\四星彩資料集", filename)
with open(file_path,'w+',encoding='utf8') as f:
    json.dump(info,f)
print(f'儲存完成... 檔案名稱:{file_path}')
# Out:
# 儲存完成... 檔案名稱:.\四星彩資料集\105000117.txt

# %%
# 關閉視窗
driver.close()
